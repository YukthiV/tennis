# %%
from keras.applications.inception_v3 import InceptionV3, preprocess_input
from keras.callbacks import TensorBoard, ModelCheckpoint, CSVLogger
from keras.optimizers import Adam
from keras.models import Model, Sequential
from keras.layers import Input, LSTM, Dense
from data_utils import DataSet

import numpy as np
import os.path
import time
# Out:
# Using TensorFlow backend.

# %%
def load_cnn_model():
    base_model = InceptionV3(weights='imagenet', include_top=True)
    
    print(base_model.summary())
#     print base_model.get_layer('global_max_pooling2d_1').output
    outputs = base_model.get_layer('avg_pool').output

    cnn_model = Model(inputs=base_model.input, outputs=outputs)

    return cnn_model

# %%
cnn_model = load_cnn_model()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 149, 149, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 149, 149, 32) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 149, 149, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 147, 147, 32) 9216        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 147, 147, 32) 96          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 147, 147, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 147, 147, 64) 18432       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 147, 147, 64) 192         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 147, 147, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 73, 73, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 73, 73, 80)   5120        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 73, 73, 80)   240         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 73, 73, 80)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 71, 71, 192)  138240      activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 71, 71, 192)  576         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 71, 71, 192)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 35, 35, 192)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 35, 35, 64)   192         conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 35, 35, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 35, 35, 48)   9216        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 35, 35, 96)   55296       activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 35, 35, 48)   144         conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 35, 35, 96)   288         conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 35, 35, 48)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 35, 35, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 35, 35, 192)  0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 35, 35, 64)   12288       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 35, 35, 64)   76800       activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 35, 35, 96)   82944       activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 35, 35, 32)   6144        average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 35, 35, 64)   192         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 35, 35, 64)   192         conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 35, 35, 96)   288         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 35, 35, 32)   96          conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 35, 35, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 35, 35, 64)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 35, 35, 96)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 35, 35, 32)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# mixed0 (Concatenate)            (None, 35, 35, 256)  0           activation_6[0][0]
#                                                                  activation_8[0][0]
#                                                                  activation_11[0][0]
#                                                                  activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 35, 35, 64)   192         conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 35, 35, 64)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 35, 35, 48)   12288       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 35, 35, 96)   55296       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 35, 35, 48)   144         conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 35, 35, 96)   288         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 35, 35, 48)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 35, 35, 96)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 35, 35, 256)  0           mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 35, 35, 64)   16384       mixed0[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 35, 35, 64)   76800       activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 35, 35, 96)   82944       activation_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 35, 35, 64)   16384       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 35, 35, 64)   192         conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 35, 35, 64)   192         conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 35, 35, 96)   288         conv2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 35, 35, 64)   192         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 35, 35, 64)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 35, 35, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 35, 35, 96)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 35, 35, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# mixed1 (Concatenate)            (None, 35, 35, 288)  0           activation_13[0][0]
#                                                                  activation_15[0][0]
#                                                                  activation_18[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 35, 35, 64)   192         conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 35, 35, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 35, 35, 48)   13824       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 35, 35, 96)   55296       activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 35, 35, 48)   144         conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 35, 35, 96)   288         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 35, 35, 48)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 35, 35, 96)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 35, 35, 288)  0           mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 35, 35, 64)   18432       mixed1[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 35, 35, 64)   76800       activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 35, 35, 96)   82944       activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 35, 35, 64)   18432       average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 35, 35, 64)   192         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 35, 35, 64)   192         conv2d_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 35, 35, 96)   288         conv2d_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 35, 35, 64)   192         conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 35, 35, 64)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 35, 35, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 35, 35, 96)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 35, 35, 64)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# mixed2 (Concatenate)            (None, 35, 35, 288)  0           activation_20[0][0]
#                                                                  activation_22[0][0]
#                                                                  activation_25[0][0]
#                                                                  activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 35, 35, 64)   18432       mixed2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 35, 35, 64)   192         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 35, 35, 64)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 35, 35, 96)   55296       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 35, 35, 96)   288         conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 35, 35, 96)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 17, 17, 384)  995328      mixed2[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 17, 17, 96)   82944       activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 17, 17, 384)  1152        conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 17, 17, 96)   288         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 17, 17, 384)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 17, 17, 96)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 17, 17, 288)  0           mixed2[0][0]
# __________________________________________________________________________________________________
# mixed3 (Concatenate)            (None, 17, 17, 768)  0           activation_27[0][0]
#                                                                  activation_30[0][0]
#                                                                  max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 17, 17, 128)  384         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 17, 17, 128)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 17, 17, 128)  114688      activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 17, 17, 128)  384         conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 17, 17, 128)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 17, 17, 128)  98304       mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 17, 17, 128)  114688      activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 17, 17, 128)  384         conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 17, 17, 128)  384         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 17, 17, 128)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 17, 17, 128)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 17, 17, 128)  114688      activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 17, 17, 128)  114688      activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 17, 17, 128)  384         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 17, 17, 128)  384         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 17, 17, 128)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 17, 17, 128)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 17, 17, 768)  0           mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 17, 17, 192)  147456      mixed3[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 17, 17, 192)  172032      activation_33[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 17, 17, 192)  172032      activation_38[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 17, 17, 192)  576         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 17, 17, 192)  576         conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 17, 17, 192)  576         conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 17, 17, 192)  576         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 17, 17, 192)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 17, 17, 192)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 17, 17, 192)  0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 17, 17, 192)  0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# mixed4 (Concatenate)            (None, 17, 17, 768)  0           activation_31[0][0]
#                                                                  activation_34[0][0]
#                                                                  activation_39[0][0]
#                                                                  activation_40[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 17, 17, 160)  480         conv2d_45[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 17, 17, 160)  0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 17, 17, 160)  179200      activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 17, 17, 160)  480         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 17, 17, 160)  0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 17, 17, 160)  122880      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 17, 17, 160)  179200      activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 17, 17, 160)  480         conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 17, 17, 160)  480         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 17, 17, 160)  0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 17, 17, 160)  0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 17, 17, 160)  179200      activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 17, 17, 160)  179200      activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 17, 17, 160)  480         conv2d_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 17, 17, 160)  480         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 17, 17, 160)  0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 17, 17, 160)  0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_5 (AveragePoo (None, 17, 17, 768)  0           mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 17, 17, 192)  147456      mixed4[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 17, 17, 192)  215040      activation_43[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 17, 17, 192)  215040      activation_48[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 17, 17, 192)  576         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 17, 17, 192)  576         conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 17, 17, 192)  576         conv2d_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 17, 17, 192)  576         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 17, 17, 192)  0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 17, 17, 192)  0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 17, 17, 192)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 17, 17, 192)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# mixed5 (Concatenate)            (None, 17, 17, 768)  0           activation_41[0][0]
#                                                                  activation_44[0][0]
#                                                                  activation_49[0][0]
#                                                                  activation_50[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 17, 17, 160)  480         conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 17, 17, 160)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 17, 17, 160)  179200      activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 17, 17, 160)  480         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 17, 17, 160)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 17, 17, 160)  122880      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 17, 17, 160)  179200      activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 17, 17, 160)  480         conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 17, 17, 160)  480         conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 17, 17, 160)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 17, 17, 160)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 17, 17, 160)  179200      activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 17, 17, 160)  179200      activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 17, 17, 160)  480         conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 17, 17, 160)  480         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 17, 17, 160)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 17, 17, 160)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_6 (AveragePoo (None, 17, 17, 768)  0           mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 17, 17, 192)  147456      mixed5[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 17, 17, 192)  215040      activation_53[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 17, 17, 192)  215040      activation_58[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 17, 17, 192)  576         conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 17, 17, 192)  576         conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 17, 17, 192)  576         conv2d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 17, 17, 192)  576         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 17, 17, 192)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 17, 17, 192)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 17, 17, 192)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 17, 17, 192)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# mixed6 (Concatenate)            (None, 17, 17, 768)  0           activation_51[0][0]
#                                                                  activation_54[0][0]
#                                                                  activation_59[0][0]
#                                                                  activation_60[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 17, 17, 192)  576         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 17, 17, 192)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 17, 17, 192)  258048      activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 17, 17, 192)  576         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 17, 17, 192)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 17, 17, 192)  258048      activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 17, 17, 192)  576         conv2d_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 17, 17, 192)  576         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 17, 17, 192)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 17, 17, 192)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 17, 17, 192)  258048      activation_62[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 17, 17, 192)  258048      activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 17, 17, 192)  576         conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 17, 17, 192)  576         conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 17, 17, 192)  0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 17, 17, 192)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_7 (AveragePoo (None, 17, 17, 768)  0           mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 17, 17, 192)  147456      mixed6[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 17, 17, 192)  258048      activation_63[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 17, 17, 192)  258048      activation_68[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 17, 17, 192)  147456      average_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 17, 17, 192)  576         conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 17, 17, 192)  576         conv2d_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 17, 17, 192)  576         conv2d_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 17, 17, 192)  576         conv2d_70[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 17, 17, 192)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 17, 17, 192)  0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 17, 17, 192)  0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 17, 17, 192)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# mixed7 (Concatenate)            (None, 17, 17, 768)  0           activation_61[0][0]
#                                                                  activation_64[0][0]
#                                                                  activation_69[0][0]
#                                                                  activation_70[0][0]
# __________________________________________________________________________________________________
# ...
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 17, 17, 192)  0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 8, 8, 320)    552960      activation_71[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 8, 8, 192)    331776      activation_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 8, 8, 320)    960         conv2d_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 8, 8, 192)    576         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 8, 8, 320)    0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 8, 8, 192)    0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 768)    0           mixed7[0][0]
# __________________________________________________________________________________________________
# mixed8 (Concatenate)            (None, 8, 8, 1280)   0           activation_72[0][0]
#                                                                  activation_76[0][0]
#                                                                  max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 8, 8, 448)    573440      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 8, 8, 448)    1344        conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 8, 8, 448)    0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 8, 8, 384)    491520      mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 8, 8, 384)    1548288     activation_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 8, 8, 384)    1152        conv2d_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 8, 8, 384)    1152        conv2d_82[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 8, 8, 384)    0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 8, 8, 384)    0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 8, 8, 384)    442368      activation_78[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 8, 8, 384)    442368      activation_78[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 8, 8, 384)    442368      activation_82[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 8, 8, 384)    442368      activation_82[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_8 (AveragePoo (None, 8, 8, 1280)   0           mixed8[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 8, 8, 320)    409600      mixed8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 8, 8, 384)    1152        conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 8, 8, 384)    1152        conv2d_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 8, 8, 384)    1152        conv2d_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 8, 8, 384)    1152        conv2d_84[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 8, 8, 192)    245760      average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 8, 8, 320)    960         conv2d_77[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 8, 8, 384)    0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 8, 8, 384)    0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 8, 8, 384)    0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 8, 8, 384)    0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 8, 8, 192)    576         conv2d_85[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 8, 8, 320)    0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# mixed9_0 (Concatenate)          (None, 8, 8, 768)    0           activation_79[0][0]
#                                                                  activation_80[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 768)    0           activation_83[0][0]
#                                                                  activation_84[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 8, 8, 192)    0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# mixed9 (Concatenate)            (None, 8, 8, 2048)   0           activation_77[0][0]
#                                                                  mixed9_0[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  activation_85[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 8, 8, 448)    917504      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 8, 8, 448)    1344        conv2d_90[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 8, 8, 448)    0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 8, 8, 384)    786432      mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 8, 8, 384)    1548288     activation_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 8, 8, 384)    1152        conv2d_87[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 8, 8, 384)    1152        conv2d_91[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 8, 8, 384)    0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 8, 8, 384)    0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 8, 8, 384)    442368      activation_87[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 8, 8, 384)    442368      activation_87[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 8, 8, 384)    442368      activation_91[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 8, 8, 384)    442368      activation_91[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_9 (AveragePoo (None, 8, 8, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 8, 8, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 8, 8, 384)    1152        conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 8, 8, 384)    1152        conv2d_89[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 8, 8, 384)    1152        conv2d_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 8, 8, 384)    1152        conv2d_93[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 8, 8, 192)    393216      average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 8, 8, 320)    960         conv2d_86[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 8, 8, 384)    0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 8, 8, 384)    0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 8, 8, 384)    0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 8, 8, 384)    0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 8, 8, 192)    576         conv2d_94[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 8, 8, 320)    0           batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 8, 8, 768)    0           activation_88[0][0]
#                                                                  activation_89[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 768)    0           activation_92[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 8, 8, 192)    0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 8, 8, 2048)   0           activation_86[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_2[0][0]
#                                                                  activation_94[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           mixed10[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 1000)         2049000     avg_pool[0][0]
# ==================================================================================================
# Total params: 23,851,784
# Trainable params: 23,817,352
# Non-trainable params: 34,432
# __________________________________________________________________________________________________
# None

# %% [markdown]
# # Creating Sequences
#
# ## Looks to be ~ 12 seconds per video
#
# ### ~24 minutes for 120 videos, ~6.6 hrs for entire 1980 videos

# %%
# ---- RUN THE FOLLOWING CELLS TO GENERATE .NPY SEQ FOR ALL VIDEOS IN DATASET ----- # 
#      SEQUENCES THAT ALREADY EXIST WILL BE SKIPPED

seq_length = 16
dataset = DataSet(cnn_model)

# %%
dataset.data[-1]
# Out:
# ['test', 'smash', 'p29_smash_s2']

# %%
tic = time.time()

for ind, sample in enumerate(dataset.data):
    
    path = os.path.join('data', 'sequences', sample[1], sample[2] + '-' + str(seq_length) + \
        '-features.npy')
    
    if os.path.isfile(path):
        print("Sequence: {} already exists".format(ind))
    else:
        print("Generating and saving sequence: {}".format(ind))
        sequence = dataset.extract_seq_features(sample)

print("Time Elapsed: {}".format(time.time() - tic))
# Out:
# Sequence: 0 already exists
# Sequence: 1 already exists
# Sequence: 2 already exists
# Sequence: 3 already exists
# Sequence: 4 already exists
# Sequence: 5 already exists
# Sequence: 6 already exists
# Sequence: 7 already exists
# Sequence: 8 already exists
# Sequence: 9 already exists
# Sequence: 10 already exists
# Sequence: 11 already exists
# Sequence: 12 already exists
# Sequence: 13 already exists
# Sequence: 14 already exists
# Sequence: 15 already exists
# Sequence: 16 already exists
# Sequence: 17 already exists
# Sequence: 18 already exists
# Sequence: 19 already exists
# Sequence: 20 already exists
# Sequence: 21 already exists
# Sequence: 22 already exists
# Sequence: 23 already exists
# Sequence: 24 already exists
# Sequence: 25 already exists
# Sequence: 26 already exists
# Sequence: 27 already exists
# Sequence: 28 already exists
# Sequence: 29 already exists
# Sequence: 30 already exists
# Sequence: 31 already exists
# Sequence: 32 already exists
# Sequence: 33 already exists
# Sequence: 34 already exists
# Sequence: 35 already exists
# Sequence: 36 already exists
# Sequence: 37 already exists
# Sequence: 38 already exists
# Sequence: 39 already exists
# Sequence: 40 already exists
# Sequence: 41 already exists
# Sequence: 42 already exists
# Sequence: 43 already exists
# Sequence: 44 already exists
# Sequence: 45 already exists
# Sequence: 46 already exists
# Sequence: 47 already exists
# Sequence: 48 already exists
# Sequence: 49 already exists
# Sequence: 50 already exists
# Sequence: 51 already exists
# Sequence: 52 already exists
# Sequence: 53 already exists
# Sequence: 54 already exists
# Sequence: 55 already exists
# Sequence: 56 already exists
# Sequence: 57 already exists
# Sequence: 58 already exists
# Sequence: 59 already exists
# Sequence: 60 already exists
# Sequence: 61 already exists
# Sequence: 62 already exists
# Sequence: 63 already exists
# Sequence: 64 already exists
# Sequence: 65 already exists
# Sequence: 66 already exists
# Sequence: 67 already exists
# Sequence: 68 already exists
# Sequence: 69 already exists
# Sequence: 70 already exists
# Sequence: 71 already exists
# Sequence: 72 already exists
# Sequence: 73 already exists
# Sequence: 74 already exists
# Sequence: 75 already exists
# Sequence: 76 already exists
# Sequence: 77 already exists
# Sequence: 78 already exists
# Sequence: 79 already exists
# Sequence: 80 already exists
# Sequence: 81 already exists
# Sequence: 82 already exists
# Sequence: 83 already exists
# Sequence: 84 already exists
# Sequence: 85 already exists
# Sequence: 86 already exists
# Sequence: 87 already exists
# Sequence: 88 already exists
# Sequence: 89 already exists
# Sequence: 90 already exists
# Sequence: 91 already exists
# Sequence: 92 already exists
# Sequence: 93 already exists
# Sequence: 94 already exists
# Sequence: 95 already exists
# Sequence: 96 already exists
# Sequence: 97 already exists
# Sequence: 98 already exists
# Sequence: 99 already exists
# Sequence: 100 already exists
# Sequence: 101 already exists
# Sequence: 102 already exists
# Sequence: 103 already exists
# Sequence: 104 already exists
# Sequence: 105 already exists
# Sequence: 106 already exists
# Sequence: 107 already exists
# Sequence: 108 already exists
# Sequence: 109 already exists
# Sequence: 110 already exists
# Sequence: 111 already exists
# Sequence: 112 already exists
# Sequence: 113 already exists
# Sequence: 114 already exists
# Sequence: 115 already exists
# Sequence: 116 already exists
# Sequence: 117 already exists
# Sequence: 118 already exists
# Sequence: 119 already exists
# Sequence: 120 already exists
# Sequence: 121 already exists
# Sequence: 122 already exists
# Sequence: 123 already exists
# Sequence: 124 already exists
# Sequence: 125 already exists
# Sequence: 126 already exists
# Sequence: 127 already exists
# Sequence: 128 already exists
# Sequence: 129 already exists
# Sequence: 130 already exists
# Sequence: 131 already exists
# Sequence: 132 already exists
# Sequence: 133 already exists
# Sequence: 134 already exists
# Sequence: 135 already exists
# Sequence: 136 already exists
# Sequence: 137 already exists
# Sequence: 138 already exists
# Sequence: 139 already exists
# Sequence: 140 already exists
# Sequence: 141 already exists
# Sequence: 142 already exists
# Sequence: 143 already exists
# Sequence: 144 already exists
# Sequence: 145 already exists
# Sequence: 146 already exists
# Sequence: 147 already exists
# Sequence: 148 already exists
# Sequence: 149 already exists
# Sequence: 150 already exists
# Sequence: 151 already exists
# Sequence: 152 already exists
# Sequence: 153 already exists
# Sequence: 154 already exists
# Sequence: 155 already exists
# Sequence: 156 already exists
# Sequence: 157 already exists
# Sequence: 158 already exists
# Sequence: 159 already exists
# Sequence: 160 already exists
# Sequence: 161 already exists
# Sequence: 162 already exists
# Sequence: 163 already exists
# Sequence: 164 already exists
# Sequence: 165 already exists
# Sequence: 166 already exists
# Sequence: 167 already exists
# Sequence: 168 already exists
# Sequence: 169 already exists
# Sequence: 170 already exists
# Sequence: 171 already exists
# Sequence: 172 already exists
# Sequence: 173 already exists
# Sequence: 174 already exists
# Sequence: 175 already exists
# Sequence: 176 already exists
# Sequence: 177 already exists
# Sequence: 178 already exists
# Sequence: 179 already exists
# Sequence: 180 already exists
# Sequence: 181 already exists
# Sequence: 182 already exists
# Sequence: 183 already exists
# Sequence: 184 already exists
# Sequence: 185 already exists
# Sequence: 186 already exists
# Sequence: 187 already exists
# Sequence: 188 already exists
# Sequence: 189 already exists
# Sequence: 190 already exists
# Sequence: 191 already exists
# Sequence: 192 already exists
# Sequence: 193 already exists
# Sequence: 194 already exists
# Sequence: 195 already exists
# Sequence: 196 already exists
# Sequence: 197 already exists
# Sequence: 198 already exists
# Sequence: 199 already exists
# Sequence: 200 already exists
# Sequence: 201 already exists
# Sequence: 202 already exists
# Sequence: 203 already exists
# Sequence: 204 already exists
# Sequence: 205 already exists
# Sequence: 206 already exists
# Sequence: 207 already exists
# Sequence: 208 already exists
# Sequence: 209 already exists
# Sequence: 210 already exists
# Sequence: 211 already exists
# Sequence: 212 already exists
# Sequence: 213 already exists
# Sequence: 214 already exists
# Sequence: 215 already exists
# Sequence: 216 already exists
# Sequence: 217 already exists
# Sequence: 218 already exists
# Sequence: 219 already exists
# Sequence: 220 already exists
# Sequence: 221 already exists
# Sequence: 222 already exists
# Sequence: 223 already exists
# Sequence: 224 already exists
# Sequence: 225 already exists
# Sequence: 226 already exists
# Sequence: 227 already exists
# Sequence: 228 already exists
# Sequence: 229 already exists
# Sequence: 230 already exists
# Sequence: 231 already exists
# Sequence: 232 already exists
# Sequence: 233 already exists
# Sequence: 234 already exists
# Sequence: 235 already exists
# Sequence: 236 already exists
# Sequence: 237 already exists
# Sequence: 238 already exists
# Sequence: 239 already exists
# Sequence: 240 already exists
# Sequence: 241 already exists
# Sequence: 242 already exists
# Sequence: 243 already exists
# Sequence: 244 already exists
# Sequence: 245 already exists
# Sequence: 246 already exists
# Sequence: 247 already exists
# Sequence: 248 already exists
# Sequence: 249 already exists
# Sequence: 250 already exists
# Sequence: 251 already exists
# Sequence: 252 already exists
# Sequence: 253 already exists
# Sequence: 254 already exists
# Sequence: 255 already exists
# Sequence: 256 already exists
# Sequence: 257 already exists
# Sequence: 258 already exists
# Sequence: 259 already exists
# Sequence: 260 already exists
# Sequence: 261 already exists
# Sequence: 262 already exists
# Sequence: 263 already exists
# Sequence: 264 already exists
# Sequence: 265 already exists
# Sequence: 266 already exists
# Sequence: 267 already exists
# Sequence: 268 already exists
# Sequence: 269 already exists
# Sequence: 270 already exists
# Sequence: 271 already exists
# Sequence: 272 already exists
# Sequence: 273 already exists
# Sequence: 274 already exists
# Sequence: 275 already exists
# Sequence: 276 already exists
# Sequence: 277 already exists
# Sequence: 278 already exists
# Sequence: 279 already exists
# Sequence: 280 already exists
# Sequence: 281 already exists
# Sequence: 282 already exists
# Sequence: 283 already exists
# Sequence: 284 already exists
# Sequence: 285 already exists
# Sequence: 286 already exists
# Sequence: 287 already exists
# Sequence: 288 already exists
# Sequence: 289 already exists
# Sequence: 290 already exists
# Sequence: 291 already exists
# Sequence: 292 already exists
# Sequence: 293 already exists
# Sequence: 294 already exists
# Sequence: 295 already exists
# Sequence: 296 already exists
# Sequence: 297 already exists
# Sequence: 298 already exists
# Sequence: 299 already exists
# Sequence: 300 already exists
# Sequence: 301 already exists
# Sequence: 302 already exists
# Sequence: 303 already exists
# Sequence: 304 already exists
# Sequence: 305 already exists
# Sequence: 306 already exists
# Sequence: 307 already exists
# Sequence: 308 already exists
# Sequence: 309 already exists
# Sequence: 310 already exists
# Sequence: 311 already exists
# Sequence: 312 already exists
# Sequence: 313 already exists
# Sequence: 314 already exists
# Sequence: 315 already exists
# Sequence: 316 already exists
# Sequence: 317 already exists
# Sequence: 318 already exists
# Sequence: 319 already exists
# Sequence: 320 already exists
# Sequence: 321 already exists
# Sequence: 322 already exists
# Sequence: 323 already exists
# Sequence: 324 already exists
# Sequence: 325 already exists
# Sequence: 326 already exists
# Sequence: 327 already exists
# Sequence: 328 already exists
# Sequence: 329 already exists
# Sequence: 330 already exists
# Sequence: 331 already exists
# Sequence: 332 already exists
# Sequence: 333 already exists
# Sequence: 334 already exists
# Sequence: 335 already exists
# Sequence: 336 already exists
# Sequence: 337 already exists
# Sequence: 338 already exists
# Sequence: 339 already exists
# Sequence: 340 already exists
# Sequence: 341 already exists
# Sequence: 342 already exists
# Sequence: 343 already exists
# Sequence: 344 already exists
# Sequence: 345 already exists
# Sequence: 346 already exists
# Sequence: 347 already exists
# Sequence: 348 already exists
# Sequence: 349 already exists
# Sequence: 350 already exists
# Sequence: 351 already exists
# Sequence: 352 already exists
# Sequence: 353 already exists
# Sequence: 354 already exists
# Sequence: 355 already exists
# Sequence: 356 already exists
# Sequence: 357 already exists
# Sequence: 358 already exists
# Sequence: 359 already exists
# Sequence: 360 already exists
# Sequence: 361 already exists
# Sequence: 362 already exists
# Sequence: 363 already exists
# Sequence: 364 already exists
# Sequence: 365 already exists
# Sequence: 366 already exists
# Sequence: 367 already exists
# Sequence: 368 already exists
# Sequence: 369 already exists
# Sequence: 370 already exists
# Sequence: 371 already exists
# Sequence: 372 already exists
# Sequence: 373 already exists
# Sequence: 374 already exists
# Sequence: 375 already exists
# Sequence: 376 already exists
# Sequence: 377 already exists
# Sequence: 378 already exists
# Sequence: 379 already exists
# Sequence: 380 already exists
# Sequence: 381 already exists
# Sequence: 382 already exists
# Sequence: 383 already exists
# Sequence: 384 already exists
# Sequence: 385 already exists
# Sequence: 386 already exists
# Sequence: 387 already exists
# Sequence: 388 already exists
# Sequence: 389 already exists
# Sequence: 390 already exists
# Sequence: 391 already exists
# Sequence: 392 already exists
# Sequence: 393 already exists
# Sequence: 394 already exists
# Sequence: 395 already exists
# Sequence: 396 already exists
# Sequence: 397 already exists
# Sequence: 398 already exists
# Sequence: 399 already exists
# Sequence: 400 already exists
# Sequence: 401 already exists
# Sequence: 402 already exists
# Sequence: 403 already exists
# Sequence: 404 already exists
# Sequence: 405 already exists
# Sequence: 406 already exists
# Sequence: 407 already exists
# Sequence: 408 already exists
# Sequence: 409 already exists
# Sequence: 410 already exists
# Sequence: 411 already exists
# Sequence: 412 already exists
# Sequence: 413 already exists
# Sequence: 414 already exists
# Sequence: 415 already exists
# Sequence: 416 already exists
# Sequence: 417 already exists
# Sequence: 418 already exists
# Sequence: 419 already exists
# Sequence: 420 already exists
# Sequence: 421 already exists
# Sequence: 422 already exists
# Sequence: 423 already exists
# Sequence: 424 already exists
# Sequence: 425 already exists
# Sequence: 426 already exists
# Sequence: 427 already exists
# Sequence: 428 already exists
# Sequence: 429 already exists
# Sequence: 430 already exists
# Sequence: 431 already exists
# Sequence: 432 already exists
# Sequence: 433 already exists
# Sequence: 434 already exists
# Sequence: 435 already exists
# Sequence: 436 already exists
# Sequence: 437 already exists
# Sequence: 438 already exists
# Sequence: 439 already exists
# Sequence: 440 already exists
# Sequence: 441 already exists
# Sequence: 442 already exists
# Sequence: 443 already exists
# Sequence: 444 already exists
# Sequence: 445 already exists
# Sequence: 446 already exists
# Sequence: 447 already exists
# Sequence: 448 already exists
# Sequence: 449 already exists
# Sequence: 450 already exists
# Sequence: 451 already exists
# Sequence: 452 already exists
# Sequence: 453 already exists
# Sequence: 454 already exists
# Sequence: 455 already exists
# Sequence: 456 already exists
# Sequence: 457 already exists
# Sequence: 458 already exists
# Sequence: 459 already exists
# Sequence: 460 already exists
# Sequence: 461 already exists
# Sequence: 462 already exists
# Sequence: 463 already exists
# Sequence: 464 already exists
# Sequence: 465 already exists
# Sequence: 466 already exists
# Sequence: 467 already exists
# Sequence: 468 already exists
# Sequence: 469 already exists
# Sequence: 470 already exists
# Sequence: 471 already exists
# Sequence: 472 already exists
# Sequence: 473 already exists
# Sequence: 474 already exists
# Sequence: 475 already exists
# Sequence: 476 already exists
# Sequence: 477 already exists
# Sequence: 478 already exists
# Sequence: 479 already exists
# Sequence: 480 already exists
# Sequence: 481 already exists
# Sequence: 482 already exists
# Sequence: 483 already exists
# Sequence: 484 already exists
# Sequence: 485 already exists
# Sequence: 486 already exists
# Sequence: 487 already exists
# Sequence: 488 already exists
# Sequence: 489 already exists
# Sequence: 490 already exists
# Sequence: 491 already exists
# Sequence: 492 already exists
# Sequence: 493 already exists
# Sequence: 494 already exists
# Sequence: 495 already exists
# Sequence: 496 already exists
# Sequence: 497 already exists
# Sequence: 498 already exists
# Sequence: 499 already exists
# Sequence: 500 already exists
# Sequence: 501 already exists
# Sequence: 502 already exists
# Sequence: 503 already exists
# Sequence: 504 already exists
# Sequence: 505 already exists
# Sequence: 506 already exists
# Sequence: 507 already exists
# Sequence: 508 already exists
# Sequence: 509 already exists
# Sequence: 510 already exists
# Sequence: 511 already exists
# Sequence: 512 already exists
# Sequence: 513 already exists
# Sequence: 514 already exists
# Sequence: 515 already exists
# Sequence: 516 already exists
# Sequence: 517 already exists
# Sequence: 518 already exists
# Sequence: 519 already exists
# Sequence: 520 already exists
# Sequence: 521 already exists
# Sequence: 522 already exists
# Sequence: 523 already exists
# Sequence: 524 already exists
# Sequence: 525 already exists
# Sequence: 526 already exists
# Sequence: 527 already exists
# Sequence: 528 already exists
# Sequence: 529 already exists
# Sequence: 530 already exists
# Sequence: 531 already exists
# Sequence: 532 already exists
# Sequence: 533 already exists
# Sequence: 534 already exists
# Sequence: 535 already exists
# Sequence: 536 already exists
# Sequence: 537 already exists
# Sequence: 538 already exists
# Sequence: 539 already exists
# Sequence: 540 already exists
# Sequence: 541 already exists
# Sequence: 542 already exists
# Sequence: 543 already exists
# Sequence: 544 already exists
# Sequence: 545 already exists
# Sequence: 546 already exists
# Sequence: 547 already exists
# Sequence: 548 already exists
# Sequence: 549 already exists
# Sequence: 550 already exists
# Sequence: 551 already exists
# Sequence: 552 already exists
# Sequence: 553 already exists
# Sequence: 554 already exists
# Sequence: 555 already exists
# Sequence: 556 already exists
# Sequence: 557 already exists
# Sequence: 558 already exists
# Sequence: 559 already exists
# Sequence: 560 already exists
# Sequence: 561 already exists
# Sequence: 562 already exists
# Sequence: 563 already exists
# Sequence: 564 already exists
# Sequence: 565 already exists
# Sequence: 566 already exists
# Sequence: 567 already exists
# Sequence: 568 already exists
# Sequence: 569 already exists
# Sequence: 570 already exists
# Sequence: 571 already exists
# Sequence: 572 already exists
# Sequence: 573 already exists
# Sequence: 574 already exists
# Sequence: 575 already exists
# Sequence: 576 already exists
# Sequence: 577 already exists
# Sequence: 578 already exists
# Sequence: 579 already exists
# Sequence: 580 already exists
# Sequence: 581 already exists
# Sequence: 582 already exists
# Sequence: 583 already exists
# Sequence: 584 already exists
# Sequence: 585 already exists
# Sequence: 586 already exists
# Sequence: 587 already exists
# Sequence: 588 already exists
# Sequence: 589 already exists
# Sequence: 590 already exists
# Sequence: 591 already exists
# Sequence: 592 already exists
# Sequence: 593 already exists
# Sequence: 594 already exists
# Sequence: 595 already exists
# Sequence: 596 already exists
# Sequence: 597 already exists
# Sequence: 598 already exists
# Sequence: 599 already exists
# Sequence: 600 already exists
# Sequence: 601 already exists
# Sequence: 602 already exists
# Sequence: 603 already exists
# Sequence: 604 already exists
# Sequence: 605 already exists
# Sequence: 606 already exists
# Sequence: 607 already exists
# Sequence: 608 already exists
# Sequence: 609 already exists
# Sequence: 610 already exists
# Sequence: 611 already exists
# Sequence: 612 already exists
# Sequence: 613 already exists
# Sequence: 614 already exists
# Sequence: 615 already exists
# Sequence: 616 already exists
# Sequence: 617 already exists
# Sequence: 618 already exists
# Sequence: 619 already exists
# Sequence: 620 already exists
# Sequence: 621 already exists
# Sequence: 622 already exists
# Sequence: 623 already exists
# Sequence: 624 already exists
# Sequence: 625 already exists
# Sequence: 626 already exists
# Sequence: 627 already exists
# Sequence: 628 already exists
# Sequence: 629 already exists
# Sequence: 630 already exists
# Sequence: 631 already exists
# Sequence: 632 already exists
# Sequence: 633 already exists
# Sequence: 634 already exists
# Sequence: 635 already exists
# Sequence: 636 already exists
# Sequence: 637 already exists
# Sequence: 638 already exists
# Sequence: 639 already exists
# Sequence: 640 already exists
# Sequence: 641 already exists
# Sequence: 642 already exists
# Sequence: 643 already exists
# Sequence: 644 already exists
# Sequence: 645 already exists
# Sequence: 646 already exists
# Sequence: 647 already exists
# Sequence: 648 already exists
# Sequence: 649 already exists
# Sequence: 650 already exists
# Sequence: 651 already exists
# Sequence: 652 already exists
# Sequence: 653 already exists
# Sequence: 654 already exists
# Sequence: 655 already exists
# Sequence: 656 already exists
# Sequence: 657 already exists
# Sequence: 658 already exists
# Sequence: 659 already exists
# Generating and saving sequence: 660
# Generating and saving sequence: 661
# Generating and saving sequence: 662
# Generating and saving sequence: 663
# Generating and saving sequence: 664
# Generating and saving sequence: 665
# Generating and saving sequence: 666
# Generating and saving sequence: 667
# Generating and saving sequence: 668
# Generating and saving sequence: 669
# Generating and saving sequence: 670
# Generating and saving sequence: 671
# Generating and saving sequence: 672
# Generating and saving sequence: 673
# Generating and saving sequence: 674
# Generating and saving sequence: 675
# Generating and saving sequence: 676
# Generating and saving sequence: 677
# Generating and saving sequence: 678
# Generating and saving sequence: 679
# Generating and saving sequence: 680
# Generating and saving sequence: 681
# Generating and saving sequence: 682
# Generating and saving sequence: 683
# Generating and saving sequence: 684
# Generating and saving sequence: 685
# Generating and saving sequence: 686
# Generating and saving sequence: 687
# Generating and saving sequence: 688
# Generating and saving sequence: 689
# Generating and saving sequence: 690
# Generating and saving sequence: 691
# Generating and saving sequence: 692
# Generating and saving sequence: 693
# Generating and saving sequence: 694
# Generating and saving sequence: 695
# Generating and saving sequence: 696
# Generating and saving sequence: 697
# Generating and saving sequence: 698
# Generating and saving sequence: 699
# Generating and saving sequence: 700
# Generating and saving sequence: 701
# Generating and saving sequence: 702
# Generating and saving sequence: 703
# Generating and saving sequence: 704
# Generating and saving sequence: 705
# Generating and saving sequence: 706
# Generating and saving sequence: 707
# Generating and saving sequence: 708
# Generating and saving sequence: 709
# Generating and saving sequence: 710
# Generating and saving sequence: 711
# Generating and saving sequence: 712
# Generating and saving sequence: 713
# Generating and saving sequence: 714
# Generating and saving sequence: 715
# Generating and saving sequence: 716
# Generating and saving sequence: 717
# Generating and saving sequence: 718
# Generating and saving sequence: 719
# Generating and saving sequence: 720
# Generating and saving sequence: 721
# Generating and saving sequence: 722
# Generating and saving sequence: 723
# Generating and saving sequence: 724
# Generating and saving sequence: 725
# Generating and saving sequence: 726
# Generating and saving sequence: 727
# Generating and saving sequence: 728
# Generating and saving sequence: 729
# Generating and saving sequence: 730
# Generating and saving sequence: 731
# Generating and saving sequence: 732
# Generating and saving sequence: 733
# Generating and saving sequence: 734
# Generating and saving sequence: 735
# Generating and saving sequence: 736
# Generating and saving sequence: 737
# Generating and saving sequence: 738
# Generating and saving sequence: 739
# Generating and saving sequence: 740
# Generating and saving sequence: 741
# Generating and saving sequence: 742
# Generating and saving sequence: 743
# Generating and saving sequence: 744
# Generating and saving sequence: 745
# Generating and saving sequence: 746
# Generating and saving sequence: 747
# Generating and saving sequence: 748
# Generating and saving sequence: 749
# Generating and saving sequence: 750
# Generating and saving sequence: 751
# Generating and saving sequence: 752
# Generating and saving sequence: 753
# Generating and saving sequence: 754
# Generating and saving sequence: 755
# Generating and saving sequence: 756
# Generating and saving sequence: 757
# Generating and saving sequence: 758
# Generating and saving sequence: 759
# Generating and saving sequence: 760
# Generating and saving sequence: 761
# Generating and saving sequence: 762
# Generating and saving sequence: 763
# Generating and saving sequence: 764
# Generating and saving sequence: 765
# Generating and saving sequence: 766
# Generating and saving sequence: 767
# Generating and saving sequence: 768
# Generating and saving sequence: 769
# Generating and saving sequence: 770
# Generating and saving sequence: 771
# Generating and saving sequence: 772
# Generating and saving sequence: 773
# Generating and saving sequence: 774
# Generating and saving sequence: 775
# Generating and saving sequence: 776
# Generating and saving sequence: 777
# Generating and saving sequence: 778
# Generating and saving sequence: 779
# Generating and saving sequence: 780
# Generating and saving sequence: 781
# Generating and saving sequence: 782
# Generating and saving sequence: 783
# Generating and saving sequence: 784
# Generating and saving sequence: 785
# Generating and saving sequence: 786
# Generating and saving sequence: 787
# Generating and saving sequence: 788
# Generating and saving sequence: 789
# Generating and saving sequence: 790
# Generating and saving sequence: 791
# Generating and saving sequence: 792
# Generating and saving sequence: 793
# Generating and saving sequence: 794
# Generating and saving sequence: 795
# Generating and saving sequence: 796
# Generating and saving sequence: 797
# Generating and saving sequence: 798
# Generating and saving sequence: 799
# Generating and saving sequence: 800
# Generating and saving sequence: 801
# Generating and saving sequence: 802
# Generating and saving sequence: 803
# Generating and saving sequence: 804
# Generating and saving sequence: 805
# Generating and saving sequence: 806
# Generating and saving sequence: 807
# Generating and saving sequence: 808
# Generating and saving sequence: 809
# Generating and saving sequence: 810
# Generating and saving sequence: 811
# Generating and saving sequence: 812
# Generating and saving sequence: 813
# Generating and saving sequence: 814
# Generating and saving sequence: 815
# Generating and saving sequence: 816
# Generating and saving sequence: 817
# Generating and saving sequence: 818
# Generating and saving sequence: 819
# Generating and saving sequence: 820
# Generating and saving sequence: 821
# Generating and saving sequence: 822
# Generating and saving sequence: 823
# Generating and saving sequence: 824
# Generating and saving sequence: 825
# Generating and saving sequence: 826
# Generating and saving sequence: 827
# Generating and saving sequence: 828
# Generating and saving sequence: 829
# Generating and saving sequence: 830
# Generating and saving sequence: 831
# Generating and saving sequence: 832
# Generating and saving sequence: 833
# Generating and saving sequence: 834
# Generating and saving sequence: 835
# Generating and saving sequence: 836
# Generating and saving sequence: 837
# Generating and saving sequence: 838
# Generating and saving sequence: 839
# Generating and saving sequence: 840
# Generating and saving sequence: 841
# Generating and saving sequence: 842
# Generating and saving sequence: 843
# Generating and saving sequence: 844
# Generating and saving sequence: 845
# Generating and saving sequence: 846
# Generating and saving sequence: 847
# Generating and saving sequence: 848
# Generating and saving sequence: 849
# Generating and saving sequence: 850
# Generating and saving sequence: 851
# Generating and saving sequence: 852
# Generating and saving sequence: 853
# Generating and saving sequence: 854
# Generating and saving sequence: 855
# Generating and saving sequence: 856
# Generating and saving sequence: 857
# Generating and saving sequence: 858
# Generating and saving sequence: 859
# Generating and saving sequence: 860
# Generating and saving sequence: 861
# Generating and saving sequence: 862
# Generating and saving sequence: 863
# Generating and saving sequence: 864
# Generating and saving sequence: 865
# Generating and saving sequence: 866
# Generating and saving sequence: 867
# Generating and saving sequence: 868
# Generating and saving sequence: 869
# Generating and saving sequence: 870
# Generating and saving sequence: 871
# Generating and saving sequence: 872
# Generating and saving sequence: 873
# Generating and saving sequence: 874
# Generating and saving sequence: 875
# Generating and saving sequence: 876
# Generating and saving sequence: 877
# Generating and saving sequence: 878
# Generating and saving sequence: 879
# Generating and saving sequence: 880
# Generating and saving sequence: 881
# Generating and saving sequence: 882
# Generating and saving sequence: 883
# Generating and saving sequence: 884
# Generating and saving sequence: 885
# Generating and saving sequence: 886
# Generating and saving sequence: 887
# Generating and saving sequence: 888
# Generating and saving sequence: 889
# Generating and saving sequence: 890
# Generating and saving sequence: 891
# Generating and saving sequence: 892
# Generating and saving sequence: 893
# Generating and saving sequence: 894
# Generating and saving sequence: 895
# Generating and saving sequence: 896
# Generating and saving sequence: 897
# Generating and saving sequence: 898
# Generating and saving sequence: 899
# Generating and saving sequence: 900
# Generating and saving sequence: 901
# Generating and saving sequence: 902
# Generating and saving sequence: 903
# Generating and saving sequence: 904
# Generating and saving sequence: 905
# Generating and saving sequence: 906
# Generating and saving sequence: 907
# Generating and saving sequence: 908
# Generating and saving sequence: 909
# Generating and saving sequence: 910
# Generating and saving sequence: 911
# Generating and saving sequence: 912
# Generating and saving sequence: 913
# Generating and saving sequence: 914
# Generating and saving sequence: 915
# Generating and saving sequence: 916
# Generating and saving sequence: 917
# Generating and saving sequence: 918
# Generating and saving sequence: 919
# Generating and saving sequence: 920
# Generating and saving sequence: 921
# Generating and saving sequence: 922
# Generating and saving sequence: 923
# Generating and saving sequence: 924
# Generating and saving sequence: 925
# Generating and saving sequence: 926
# Generating and saving sequence: 927
# Generating and saving sequence: 928
# Generating and saving sequence: 929
# Generating and saving sequence: 930
# Generating and saving sequence: 931
# Generating and saving sequence: 932
# Generating and saving sequence: 933
# Generating and saving sequence: 934
# Generating and saving sequence: 935
# Generating and saving sequence: 936
# Generating and saving sequence: 937
# Generating and saving sequence: 938
# Generating and saving sequence: 939
# Generating and saving sequence: 940
# Generating and saving sequence: 941
# Generating and saving sequence: 942
# Generating and saving sequence: 943
# Generating and saving sequence: 944
# Generating and saving sequence: 945
# Generating and saving sequence: 946
# Generating and saving sequence: 947
# Generating and saving sequence: 948
# Generating and saving sequence: 949
# Generating and saving sequence: 950
# Generating and saving sequence: 951
# Generating and saving sequence: 952
# Generating and saving sequence: 953
# Generating and saving sequence: 954
# Generating and saving sequence: 955
# Generating and saving sequence: 956
# Generating and saving sequence: 957
# Generating and saving sequence: 958
# Generating and saving sequence: 959
# Generating and saving sequence: 960
# Generating and saving sequence: 961
# Generating and saving sequence: 962
# Generating and saving sequence: 963
# Generating and saving sequence: 964
# Generating and saving sequence: 965
# Generating and saving sequence: 966
# Generating and saving sequence: 967
# Generating and saving sequence: 968
# Generating and saving sequence: 969
# Generating and saving sequence: 970
# Generating and saving sequence: 971
# Generating and saving sequence: 972
# Generating and saving sequence: 973
# Generating and saving sequence: 974
# Generating and saving sequence: 975
# Generating and saving sequence: 976
# Generating and saving sequence: 977
# Generating and saving sequence: 978
# Generating and saving sequence: 979
# Generating and saving sequence: 980
# Generating and saving sequence: 981
# Generating and saving sequence: 982
# Generating and saving sequence: 983
# Generating and saving sequence: 984
# Generating and saving sequence: 985
# Generating and saving sequence: 986
# Generating and saving sequence: 987
# Generating and saving sequence: 988
# Generating and saving sequence: 989
# Generating and saving sequence: 990
# Generating and saving sequence: 991
# Generating and saving sequence: 992
# Generating and saving sequence: 993
# Generating and saving sequence: 994
# Generating and saving sequence: 995
# Generating and saving sequence: 996
# Generating and saving sequence: 997
# Generating and saving sequence: 998
# Generating and saving sequence: 999
# Generating and saving sequence: 1000
# Generating and saving sequence: 1001
# Generating and saving sequence: 1002
# Generating and saving sequence: 1003
# Generating and saving sequence: 1004
# Generating and saving sequence: 1005
# Generating and saving sequence: 1006
# Generating and saving sequence: 1007
# Generating and saving sequence: 1008
# Generating and saving sequence: 1009
# Generating and saving sequence: 1010
# Generating and saving sequence: 1011
# Generating and saving sequence: 1012
# Generating and saving sequence: 1013
# Generating and saving sequence: 1014
# Generating and saving sequence: 1015
# Generating and saving sequence: 1016
# Generating and saving sequence: 1017
# Generating and saving sequence: 1018
# Generating and saving sequence: 1019
# Generating and saving sequence: 1020
# Generating and saving sequence: 1021
# Generating and saving sequence: 1022
# Generating and saving sequence: 1023
# Generating and saving sequence: 1024
# Generating and saving sequence: 1025
# Generating and saving sequence: 1026
# Generating and saving sequence: 1027
# Generating and saving sequence: 1028
# Generating and saving sequence: 1029
# Generating and saving sequence: 1030
# Generating and saving sequence: 1031
# Generating and saving sequence: 1032
# Generating and saving sequence: 1033
# Generating and saving sequence: 1034
# Generating and saving sequence: 1035
# Generating and saving sequence: 1036
# Generating and saving sequence: 1037
# Generating and saving sequence: 1038
# Generating and saving sequence: 1039
# Generating and saving sequence: 1040
# Generating and saving sequence: 1041
# Generating and saving sequence: 1042
# Generating and saving sequence: 1043
# Generating and saving sequence: 1044
# Generating and saving sequence: 1045
# Generating and saving sequence: 1046
# Generating and saving sequence: 1047
# Generating and saving sequence: 1048
# Generating and saving sequence: 1049
# Generating and saving sequence: 1050
# Generating and saving sequence: 1051
# Generating and saving sequence: 1052
# Generating and saving sequence: 1053
# Generating and saving sequence: 1054
# Generating and saving sequence: 1055
# Generating and saving sequence: 1056
# Generating and saving sequence: 1057
# Generating and saving sequence: 1058
# Generating and saving sequence: 1059
# Generating and saving sequence: 1060
# Generating and saving sequence: 1061
# Generating and saving sequence: 1062
# Generating and saving sequence: 1063
# Generating and saving sequence: 1064
# Generating and saving sequence: 1065
# Generating and saving sequence: 1066
# Generating and saving sequence: 1067
# Generating and saving sequence: 1068
# Generating and saving sequence: 1069
# Generating and saving sequence: 1070
# Generating and saving sequence: 1071
# Generating and saving sequence: 1072
# Generating and saving sequence: 1073
# Generating and saving sequence: 1074
# Generating and saving sequence: 1075
# Generating and saving sequence: 1076
# Generating and saving sequence: 1077
# Generating and saving sequence: 1078
# Generating and saving sequence: 1079
# Generating and saving sequence: 1080
# Generating and saving sequence: 1081
# Generating and saving sequence: 1082
# Generating and saving sequence: 1083
# Generating and saving sequence: 1084
# Generating and saving sequence: 1085
# Generating and saving sequence: 1086
# Generating and saving sequence: 1087
# Generating and saving sequence: 1088
# Generating and saving sequence: 1089
# Generating and saving sequence: 1090
# Generating and saving sequence: 1091
# Generating and saving sequence: 1092
# Generating and saving sequence: 1093
# Generating and saving sequence: 1094
# Generating and saving sequence: 1095
# Generating and saving sequence: 1096
# Generating and saving sequence: 1097
# Generating and saving sequence: 1098
# Generating and saving sequence: 1099
# Generating and saving sequence: 1100
# Generating and saving sequence: 1101
# Generating and saving sequence: 1102
# Generating and saving sequence: 1103
# Generating and saving sequence: 1104
# Generating and saving sequence: 1105
# Generating and saving sequence: 1106
# Generating and saving sequence: 1107
# Generating and saving sequence: 1108
# Generating and saving sequence: 1109
# Generating and saving sequence: 1110
# Generating and saving sequence: 1111
# Generating and saving sequence: 1112
# Generating and saving sequence: 1113
# Generating and saving sequence: 1114
# Generating and saving sequence: 1115
# Generating and saving sequence: 1116
# Generating and saving sequence: 1117
# Generating and saving sequence: 1118
# Generating and saving sequence: 1119
# Generating and saving sequence: 1120
# Generating and saving sequence: 1121
# Generating and saving sequence: 1122
# Generating and saving sequence: 1123
# Generating and saving sequence: 1124
# Generating and saving sequence: 1125
# Generating and saving sequence: 1126
# Generating and saving sequence: 1127
# Generating and saving sequence: 1128
# Generating and saving sequence: 1129
# Generating and saving sequence: 1130
# Generating and saving sequence: 1131
# Generating and saving sequence: 1132
# Generating and saving sequence: 1133
# Generating and saving sequence: 1134
# Generating and saving sequence: 1135
# Generating and saving sequence: 1136
# Generating and saving sequence: 1137
# Generating and saving sequence: 1138
# Generating and saving sequence: 1139
# Generating and saving sequence: 1140
# Generating and saving sequence: 1141
# Generating and saving sequence: 1142
# Generating and saving sequence: 1143
# Generating and saving sequence: 1144
# Generating and saving sequence: 1145
# Generating and saving sequence: 1146
# Generating and saving sequence: 1147
# Generating and saving sequence: 1148
# Generating and saving sequence: 1149
# Generating and saving sequence: 1150
# Generating and saving sequence: 1151
# Generating and saving sequence: 1152
# Generating and saving sequence: 1153
# Generating and saving sequence: 1154
# Generating and saving sequence: 1155
# Generating and saving sequence: 1156
# Generating and saving sequence: 1157
# Generating and saving sequence: 1158
# Generating and saving sequence: 1159
# Generating and saving sequence: 1160
# Generating and saving sequence: 1161
# Generating and saving sequence: 1162
# Generating and saving sequence: 1163
# Generating and saving sequence: 1164
# Generating and saving sequence: 1165
# Generating and saving sequence: 1166
# Generating and saving sequence: 1167
# Generating and saving sequence: 1168
# Generating and saving sequence: 1169
# Generating and saving sequence: 1170
# Generating and saving sequence: 1171
# Generating and saving sequence: 1172
# Generating and saving sequence: 1173
# Generating and saving sequence: 1174
# Generating and saving sequence: 1175
# Generating and saving sequence: 1176
# Generating and saving sequence: 1177
# Generating and saving sequence: 1178
# Generating and saving sequence: 1179
# Generating and saving sequence: 1180
# Generating and saving sequence: 1181
# Generating and saving sequence: 1182
# Generating and saving sequence: 1183
# Generating and saving sequence: 1184
# Generating and saving sequence: 1185
# Generating and saving sequence: 1186
# Generating and saving sequence: 1187
# Generating and saving sequence: 1188
# Generating and saving sequence: 1189
# Generating and saving sequence: 1190
# Generating and saving sequence: 1191
# Generating and saving sequence: 1192
# Generating and saving sequence: 1193
# Generating and saving sequence: 1194
# Generating and saving sequence: 1195
# Generating and saving sequence: 1196
# Generating and saving sequence: 1197
# Generating and saving sequence: 1198
# Generating and saving sequence: 1199
# Generating and saving sequence: 1200
# Generating and saving sequence: 1201
# Generating and saving sequence: 1202
# Generating and saving sequence: 1203
# Generating and saving sequence: 1204
# Generating and saving sequence: 1205
# Generating and saving sequence: 1206
# Generating and saving sequence: 1207
# Generating and saving sequence: 1208
# Generating and saving sequence: 1209
# Generating and saving sequence: 1210
# Generating and saving sequence: 1211
# Generating and saving sequence: 1212
# Generating and saving sequence: 1213
# Generating and saving sequence: 1214
# Generating and saving sequence: 1215
# Generating and saving sequence: 1216
# Generating and saving sequence: 1217
# Generating and saving sequence: 1218
# Generating and saving sequence: 1219
# Generating and saving sequence: 1220
# Generating and saving sequence: 1221
# Generating and saving sequence: 1222
# Generating and saving sequence: 1223
# Generating and saving sequence: 1224
# Generating and saving sequence: 1225
# Generating and saving sequence: 1226
# Generating and saving sequence: 1227
# Generating and saving sequence: 1228
# Generating and saving sequence: 1229
# Generating and saving sequence: 1230
# Generating and saving sequence: 1231
# Generating and saving sequence: 1232
# Generating and saving sequence: 1233
# Generating and saving sequence: 1234
# Generating and saving sequence: 1235
# Generating and saving sequence: 1236
# Generating and saving sequence: 1237
# Generating and saving sequence: 1238
# Generating and saving sequence: 1239
# Generating and saving sequence: 1240
# Generating and saving sequence: 1241
# Generating and saving sequence: 1242
# Generating and saving sequence: 1243
# Generating and saving sequence: 1244
# Generating and saving sequence: 1245
# Generating and saving sequence: 1246
# Generating and saving sequence: 1247
# Generating and saving sequence: 1248
# Generating and saving sequence: 1249
# Generating and saving sequence: 1250
# Generating and saving sequence: 1251
# Generating and saving sequence: 1252
# Generating and saving sequence: 1253
# Generating and saving sequence: 1254
# Generating and saving sequence: 1255
# Generating and saving sequence: 1256
# Generating and saving sequence: 1257
# Generating and saving sequence: 1258
# Generating and saving sequence: 1259
# Generating and saving sequence: 1260
# Generating and saving sequence: 1261
# Generating and saving sequence: 1262
# Generating and saving sequence: 1263
# Generating and saving sequence: 1264
# Generating and saving sequence: 1265
# Generating and saving sequence: 1266
# Generating and saving sequence: 1267
# Generating and saving sequence: 1268
# Generating and saving sequence: 1269
# Generating and saving sequence: 1270
# Generating and saving sequence: 1271
# Generating and saving sequence: 1272
# Generating and saving sequence: 1273
# Generating and saving sequence: 1274
# Generating and saving sequence: 1275
# Generating and saving sequence: 1276
# Generating and saving sequence: 1277
# Generating and saving sequence: 1278
# Generating and saving sequence: 1279
# Generating and saving sequence: 1280
# Generating and saving sequence: 1281
# Generating and saving sequence: 1282
# Generating and saving sequence: 1283
# Generating and saving sequence: 1284
# Generating and saving sequence: 1285
# Generating and saving sequence: 1286
# Generating and saving sequence: 1287
# Generating and saving sequence: 1288
# Generating and saving sequence: 1289
# Generating and saving sequence: 1290
# Generating and saving sequence: 1291
# Generating and saving sequence: 1292
# Generating and saving sequence: 1293
# Generating and saving sequence: 1294
# Generating and saving sequence: 1295
# Generating and saving sequence: 1296
# Generating and saving sequence: 1297
# Generating and saving sequence: 1298
# Generating and saving sequence: 1299
# Generating and saving sequence: 1300
# Generating and saving sequence: 1301
# Generating and saving sequence: 1302
# Generating and saving sequence: 1303
# Generating and saving sequence: 1304
# Generating and saving sequence: 1305
# Generating and saving sequence: 1306
# Generating and saving sequence: 1307
# Generating and saving sequence: 1308
# Generating and saving sequence: 1309
# Generating and saving sequence: 1310
# Generating and saving sequence: 1311
# Generating and saving sequence: 1312
# Generating and saving sequence: 1313
# Generating and saving sequence: 1314
# Generating and saving sequence: 1315
# Generating and saving sequence: 1316
# Generating and saving sequence: 1317
# Generating and saving sequence: 1318
# Generating and saving sequence: 1319
# Generating and saving sequence: 1320
# Generating and saving sequence: 1321
# Generating and saving sequence: 1322
# Generating and saving sequence: 1323
# Generating and saving sequence: 1324
# Generating and saving sequence: 1325
# Generating and saving sequence: 1326
# Generating and saving sequence: 1327
# Generating and saving sequence: 1328
# Generating and saving sequence: 1329
# Generating and saving sequence: 1330
# Generating and saving sequence: 1331
# Generating and saving sequence: 1332
# Generating and saving sequence: 1333
# Generating and saving sequence: 1334
# Generating and saving sequence: 1335
# Generating and saving sequence: 1336
# Generating and saving sequence: 1337
# Generating and saving sequence: 1338
# Generating and saving sequence: 1339
# Generating and saving sequence: 1340
# Generating and saving sequence: 1341
# Generating and saving sequence: 1342
# Generating and saving sequence: 1343
# Generating and saving sequence: 1344
# Generating and saving sequence: 1345
# Generating and saving sequence: 1346
# Generating and saving sequence: 1347
# Generating and saving sequence: 1348
# Generating and saving sequence: 1349
# Generating and saving sequence: 1350
# Generating and saving sequence: 1351
# Generating and saving sequence: 1352
# Generating and saving sequence: 1353
# Generating and saving sequence: 1354
# Generating and saving sequence: 1355
# Generating and saving sequence: 1356
# Generating and saving sequence: 1357
# Generating and saving sequence: 1358
# Generating and saving sequence: 1359
# Generating and saving sequence: 1360
# Generating and saving sequence: 1361
# Generating and saving sequence: 1362
# Generating and saving sequence: 1363
# Generating and saving sequence: 1364
# Generating and saving sequence: 1365
# Generating and saving sequence: 1366
# Generating and saving sequence: 1367
# Generating and saving sequence: 1368
# Generating and saving sequence: 1369
# Generating and saving sequence: 1370
# Generating and saving sequence: 1371
# Generating and saving sequence: 1372
# Generating and saving sequence: 1373
# Generating and saving sequence: 1374
# Generating and saving sequence: 1375
# Generating and saving sequence: 1376
# Generating and saving sequence: 1377
# Generating and saving sequence: 1378
# Generating and saving sequence: 1379
# Generating and saving sequence: 1380
# Generating and saving sequence: 1381
# Generating and saving sequence: 1382
# Generating and saving sequence: 1383
# Generating and saving sequence: 1384
# Generating and saving sequence: 1385
# Generating and saving sequence: 1386
# Generating and saving sequence: 1387
# Generating and saving sequence: 1388
# Generating and saving sequence: 1389
# Generating and saving sequence: 1390
# Generating and saving sequence: 1391
# Generating and saving sequence: 1392
# Generating and saving sequence: 1393
# Generating and saving sequence: 1394
# Generating and saving sequence: 1395
# Generating and saving sequence: 1396
# Generating and saving sequence: 1397
# Generating and saving sequence: 1398
# Generating and saving sequence: 1399
# Generating and saving sequence: 1400
# Generating and saving sequence: 1401
# Generating and saving sequence: 1402
# Generating and saving sequence: 1403
# Generating and saving sequence: 1404
# Generating and saving sequence: 1405
# Generating and saving sequence: 1406
# Generating and saving sequence: 1407
# Generating and saving sequence: 1408
# Generating and saving sequence: 1409
# Generating and saving sequence: 1410
# Generating and saving sequence: 1411
# Generating and saving sequence: 1412
# Generating and saving sequence: 1413
# Generating and saving sequence: 1414
# Generating and saving sequence: 1415
# Generating and saving sequence: 1416
# Generating and saving sequence: 1417
# Generating and saving sequence: 1418
# Generating and saving sequence: 1419
# Generating and saving sequence: 1420
# Generating and saving sequence: 1421
# Generating and saving sequence: 1422
# Generating and saving sequence: 1423
# Generating and saving sequence: 1424
# Generating and saving sequence: 1425
# Generating and saving sequence: 1426
# Generating and saving sequence: 1427
# Generating and saving sequence: 1428
# Generating and saving sequence: 1429
# Generating and saving sequence: 1430
# Generating and saving sequence: 1431
# Generating and saving sequence: 1432
# Generating and saving sequence: 1433
# Generating and saving sequence: 1434
# Generating and saving sequence: 1435
# Generating and saving sequence: 1436
# Generating and saving sequence: 1437
# Generating and saving sequence: 1438
# Generating and saving sequence: 1439
# Generating and saving sequence: 1440
# Generating and saving sequence: 1441
# Generating and saving sequence: 1442
# Generating and saving sequence: 1443
# Generating and saving sequence: 1444
# Generating and saving sequence: 1445
# Generating and saving sequence: 1446
# Generating and saving sequence: 1447
# Generating and saving sequence: 1448
# Generating and saving sequence: 1449
# Generating and saving sequence: 1450
# Generating and saving sequence: 1451
# ...
# Generating and saving sequence: 1549
# Generating and saving sequence: 1550
# Generating and saving sequence: 1551
# Generating and saving sequence: 1552
# Generating and saving sequence: 1553
# Generating and saving sequence: 1554
# Generating and saving sequence: 1555
# Generating and saving sequence: 1556
# Generating and saving sequence: 1557
# Generating and saving sequence: 1558
# Generating and saving sequence: 1559
# Generating and saving sequence: 1560
# Generating and saving sequence: 1561
# Generating and saving sequence: 1562
# Generating and saving sequence: 1563
# Generating and saving sequence: 1564
# Generating and saving sequence: 1565
# Generating and saving sequence: 1566
# Generating and saving sequence: 1567
# Generating and saving sequence: 1568
# Generating and saving sequence: 1569
# Generating and saving sequence: 1570
# Generating and saving sequence: 1571
# Generating and saving sequence: 1572
# Generating and saving sequence: 1573
# Generating and saving sequence: 1574
# Generating and saving sequence: 1575
# Generating and saving sequence: 1576
# Generating and saving sequence: 1577
# Generating and saving sequence: 1578
# Generating and saving sequence: 1579
# Generating and saving sequence: 1580
# Generating and saving sequence: 1581
# Generating and saving sequence: 1582
# Generating and saving sequence: 1583
# Generating and saving sequence: 1584
# Generating and saving sequence: 1585
# Generating and saving sequence: 1586
# Generating and saving sequence: 1587
# Generating and saving sequence: 1588
# Generating and saving sequence: 1589
# Generating and saving sequence: 1590
# Generating and saving sequence: 1591
# Generating and saving sequence: 1592
# Generating and saving sequence: 1593
# Generating and saving sequence: 1594
# Generating and saving sequence: 1595
# Generating and saving sequence: 1596
# Generating and saving sequence: 1597
# Generating and saving sequence: 1598
# Generating and saving sequence: 1599
# Generating and saving sequence: 1600
# Generating and saving sequence: 1601
# Generating and saving sequence: 1602
# Generating and saving sequence: 1603
# Generating and saving sequence: 1604
# Generating and saving sequence: 1605
# Generating and saving sequence: 1606
# Generating and saving sequence: 1607
# Generating and saving sequence: 1608
# Generating and saving sequence: 1609
# Generating and saving sequence: 1610
# Generating and saving sequence: 1611
# Generating and saving sequence: 1612
# Generating and saving sequence: 1613
# Generating and saving sequence: 1614
# Generating and saving sequence: 1615
# Generating and saving sequence: 1616
# Generating and saving sequence: 1617
# Generating and saving sequence: 1618
# Generating and saving sequence: 1619
# Generating and saving sequence: 1620
# Generating and saving sequence: 1621
# Generating and saving sequence: 1622
# Generating and saving sequence: 1623
# Generating and saving sequence: 1624
# Generating and saving sequence: 1625
# Generating and saving sequence: 1626
# Generating and saving sequence: 1627
# Generating and saving sequence: 1628
# Generating and saving sequence: 1629
# Generating and saving sequence: 1630
# Generating and saving sequence: 1631
# Generating and saving sequence: 1632
# Generating and saving sequence: 1633
# Generating and saving sequence: 1634
# Generating and saving sequence: 1635
# Generating and saving sequence: 1636
# Generating and saving sequence: 1637
# Generating and saving sequence: 1638
# Generating and saving sequence: 1639
# Generating and saving sequence: 1640
# Generating and saving sequence: 1641
# Generating and saving sequence: 1642
# Generating and saving sequence: 1643
# Generating and saving sequence: 1644
# Generating and saving sequence: 1645
# Generating and saving sequence: 1646
# Generating and saving sequence: 1647
# Generating and saving sequence: 1648
# Generating and saving sequence: 1649
# Generating and saving sequence: 1650
# Generating and saving sequence: 1651
# Generating and saving sequence: 1652
# Generating and saving sequence: 1653
# Generating and saving sequence: 1654
# Generating and saving sequence: 1655
# Generating and saving sequence: 1656
# Generating and saving sequence: 1657
# Generating and saving sequence: 1658
# Generating and saving sequence: 1659
# Generating and saving sequence: 1660
# Generating and saving sequence: 1661
# Generating and saving sequence: 1662
# Generating and saving sequence: 1663
# Generating and saving sequence: 1664
# Generating and saving sequence: 1665
# Generating and saving sequence: 1666
# Generating and saving sequence: 1667
# Generating and saving sequence: 1668
# Generating and saving sequence: 1669
# Generating and saving sequence: 1670
# Generating and saving sequence: 1671
# Generating and saving sequence: 1672
# Generating and saving sequence: 1673
# Generating and saving sequence: 1674
# Generating and saving sequence: 1675
# Generating and saving sequence: 1676
# Generating and saving sequence: 1677
# Generating and saving sequence: 1678
# Generating and saving sequence: 1679
# Generating and saving sequence: 1680
# Generating and saving sequence: 1681
# Generating and saving sequence: 1682
# Generating and saving sequence: 1683
# Generating and saving sequence: 1684
# Generating and saving sequence: 1685
# Generating and saving sequence: 1686
# Generating and saving sequence: 1687
# Generating and saving sequence: 1688
# Generating and saving sequence: 1689
# Generating and saving sequence: 1690
# Generating and saving sequence: 1691
# Generating and saving sequence: 1692
# Generating and saving sequence: 1693
# Generating and saving sequence: 1694
# Generating and saving sequence: 1695
# Generating and saving sequence: 1696
# Generating and saving sequence: 1697
# Generating and saving sequence: 1698
# Generating and saving sequence: 1699
# Generating and saving sequence: 1700
# Generating and saving sequence: 1701
# Generating and saving sequence: 1702
# Generating and saving sequence: 1703
# Generating and saving sequence: 1704
# Generating and saving sequence: 1705
# Generating and saving sequence: 1706
# Generating and saving sequence: 1707
# Generating and saving sequence: 1708
# Generating and saving sequence: 1709
# Generating and saving sequence: 1710
# Generating and saving sequence: 1711
# Generating and saving sequence: 1712
# Generating and saving sequence: 1713
# Generating and saving sequence: 1714
# Generating and saving sequence: 1715
# Generating and saving sequence: 1716
# Generating and saving sequence: 1717
# Generating and saving sequence: 1718
# Generating and saving sequence: 1719
# Generating and saving sequence: 1720
# Generating and saving sequence: 1721
# Generating and saving sequence: 1722
# Generating and saving sequence: 1723
# Generating and saving sequence: 1724
# Generating and saving sequence: 1725
# Generating and saving sequence: 1726
# Generating and saving sequence: 1727
# Generating and saving sequence: 1728
# Generating and saving sequence: 1729
# Generating and saving sequence: 1730
# Generating and saving sequence: 1731
# Generating and saving sequence: 1732
# Generating and saving sequence: 1733
# Generating and saving sequence: 1734
# Generating and saving sequence: 1735
# Generating and saving sequence: 1736
# Generating and saving sequence: 1737
# Generating and saving sequence: 1738
# Generating and saving sequence: 1739
# Generating and saving sequence: 1740
# Generating and saving sequence: 1741
# Generating and saving sequence: 1742
# Generating and saving sequence: 1743
# Generating and saving sequence: 1744
# Generating and saving sequence: 1745
# Generating and saving sequence: 1746
# Generating and saving sequence: 1747
# Generating and saving sequence: 1748
# Generating and saving sequence: 1749
# Generating and saving sequence: 1750
# Generating and saving sequence: 1751
# Generating and saving sequence: 1752
# Generating and saving sequence: 1753
# Generating and saving sequence: 1754
# Generating and saving sequence: 1755
# Generating and saving sequence: 1756
# Generating and saving sequence: 1757
# Generating and saving sequence: 1758
# Generating and saving sequence: 1759
# Generating and saving sequence: 1760
# Generating and saving sequence: 1761
# Generating and saving sequence: 1762
# Generating and saving sequence: 1763
# Generating and saving sequence: 1764
# Generating and saving sequence: 1765
# Generating and saving sequence: 1766
# Generating and saving sequence: 1767
# Generating and saving sequence: 1768
# Generating and saving sequence: 1769
# Generating and saving sequence: 1770
# Generating and saving sequence: 1771
# Generating and saving sequence: 1772
# Generating and saving sequence: 1773
# Generating and saving sequence: 1774
# Generating and saving sequence: 1775
# Generating and saving sequence: 1776
# Generating and saving sequence: 1777
# Generating and saving sequence: 1778
# Generating and saving sequence: 1779
# Generating and saving sequence: 1780
# Generating and saving sequence: 1781
# Generating and saving sequence: 1782
# Generating and saving sequence: 1783
# Generating and saving sequence: 1784
# Generating and saving sequence: 1785
# Generating and saving sequence: 1786
# Generating and saving sequence: 1787
# Generating and saving sequence: 1788
# Generating and saving sequence: 1789
# Generating and saving sequence: 1790
# Generating and saving sequence: 1791
# Generating and saving sequence: 1792
# Generating and saving sequence: 1793
# Generating and saving sequence: 1794
# Generating and saving sequence: 1795
# Generating and saving sequence: 1796
# Generating and saving sequence: 1797
# Generating and saving sequence: 1798
# Generating and saving sequence: 1799
# Generating and saving sequence: 1800
# Generating and saving sequence: 1801
# Generating and saving sequence: 1802
# Generating and saving sequence: 1803
# Generating and saving sequence: 1804
# Generating and saving sequence: 1805
# Generating and saving sequence: 1806
# Generating and saving sequence: 1807
# Generating and saving sequence: 1808
# Generating and saving sequence: 1809
# Generating and saving sequence: 1810
# Generating and saving sequence: 1811
# Generating and saving sequence: 1812
# Generating and saving sequence: 1813
# Generating and saving sequence: 1814
# Generating and saving sequence: 1815
# Generating and saving sequence: 1816
# Generating and saving sequence: 1817
# Generating and saving sequence: 1818
# Generating and saving sequence: 1819
# Generating and saving sequence: 1820
# Generating and saving sequence: 1821
# Generating and saving sequence: 1822
# Generating and saving sequence: 1823
# Generating and saving sequence: 1824
# Generating and saving sequence: 1825
# Generating and saving sequence: 1826
# Generating and saving sequence: 1827
# Generating and saving sequence: 1828
# Generating and saving sequence: 1829
# Generating and saving sequence: 1830
# Generating and saving sequence: 1831
# Generating and saving sequence: 1832
# Generating and saving sequence: 1833
# Generating and saving sequence: 1834
# Generating and saving sequence: 1835
# Generating and saving sequence: 1836
# Generating and saving sequence: 1837
# Generating and saving sequence: 1838
# Generating and saving sequence: 1839
# Generating and saving sequence: 1840
# Generating and saving sequence: 1841
# Generating and saving sequence: 1842
# Generating and saving sequence: 1843
# Generating and saving sequence: 1844
# Generating and saving sequence: 1845
# Generating and saving sequence: 1846
# Generating and saving sequence: 1847
# Generating and saving sequence: 1848
# Generating and saving sequence: 1849
# Generating and saving sequence: 1850
# Generating and saving sequence: 1851
# Generating and saving sequence: 1852
# Generating and saving sequence: 1853
# Generating and saving sequence: 1854
# Generating and saving sequence: 1855
# Generating and saving sequence: 1856
# Generating and saving sequence: 1857
# Generating and saving sequence: 1858
# Generating and saving sequence: 1859
# Generating and saving sequence: 1860
# Generating and saving sequence: 1861
# Generating and saving sequence: 1862
# Generating and saving sequence: 1863
# Generating and saving sequence: 1864
# Generating and saving sequence: 1865
# Generating and saving sequence: 1866
# Generating and saving sequence: 1867
# Generating and saving sequence: 1868
# Generating and saving sequence: 1869
# Generating and saving sequence: 1870
# Generating and saving sequence: 1871
# Generating and saving sequence: 1872
# Generating and saving sequence: 1873
# Generating and saving sequence: 1874
# Generating and saving sequence: 1875
# Generating and saving sequence: 1876
# Generating and saving sequence: 1877
# Generating and saving sequence: 1878
# Generating and saving sequence: 1879
# Generating and saving sequence: 1880
# Generating and saving sequence: 1881
# Generating and saving sequence: 1882
# Generating and saving sequence: 1883
# Generating and saving sequence: 1884
# Generating and saving sequence: 1885
# Generating and saving sequence: 1886
# Generating and saving sequence: 1887
# Generating and saving sequence: 1888
# Generating and saving sequence: 1889
# Generating and saving sequence: 1890
# Generating and saving sequence: 1891
# Generating and saving sequence: 1892
# Generating and saving sequence: 1893
# Generating and saving sequence: 1894
# Generating and saving sequence: 1895
# Generating and saving sequence: 1896
# Generating and saving sequence: 1897
# Generating and saving sequence: 1898
# Generating and saving sequence: 1899
# Generating and saving sequence: 1900
# Generating and saving sequence: 1901
# Generating and saving sequence: 1902
# Generating and saving sequence: 1903
# Generating and saving sequence: 1904
# Generating and saving sequence: 1905
# Generating and saving sequence: 1906
# Generating and saving sequence: 1907
# Generating and saving sequence: 1908
# Generating and saving sequence: 1909
# Generating and saving sequence: 1910
# Generating and saving sequence: 1911
# Generating and saving sequence: 1912
# Generating and saving sequence: 1913
# Generating and saving sequence: 1914
# Generating and saving sequence: 1915
# Generating and saving sequence: 1916
# Generating and saving sequence: 1917
# Generating and saving sequence: 1918
# Generating and saving sequence: 1919
# Generating and saving sequence: 1920
# Generating and saving sequence: 1921
# Generating and saving sequence: 1922
# Generating and saving sequence: 1923
# Generating and saving sequence: 1924
# Generating and saving sequence: 1925
# Generating and saving sequence: 1926
# Generating and saving sequence: 1927
# Generating and saving sequence: 1928
# Generating and saving sequence: 1929
# Generating and saving sequence: 1930
# Generating and saving sequence: 1931
# Generating and saving sequence: 1932
# Generating and saving sequence: 1933
# Generating and saving sequence: 1934
# Generating and saving sequence: 1935
# Generating and saving sequence: 1936
# Generating and saving sequence: 1937
# Generating and saving sequence: 1938
# Generating and saving sequence: 1939
# Generating and saving sequence: 1940
# Generating and saving sequence: 1941
# Generating and saving sequence: 1942
# Generating and saving sequence: 1943
# Generating and saving sequence: 1944
# Generating and saving sequence: 1945
# Generating and saving sequence: 1946
# Generating and saving sequence: 1947
# Generating and saving sequence: 1948
# Generating and saving sequence: 1949
# Generating and saving sequence: 1950
# Generating and saving sequence: 1951
# Generating and saving sequence: 1952
# Generating and saving sequence: 1953
# Generating and saving sequence: 1954
# Generating and saving sequence: 1955
# Generating and saving sequence: 1956
# Generating and saving sequence: 1957
# Generating and saving sequence: 1958
# Generating and saving sequence: 1959
# Generating and saving sequence: 1960
# Generating and saving sequence: 1961
# Generating and saving sequence: 1962
# Generating and saving sequence: 1963
# Generating and saving sequence: 1964
# Generating and saving sequence: 1965
# Generating and saving sequence: 1966
# Generating and saving sequence: 1967
# Generating and saving sequence: 1968
# Generating and saving sequence: 1969
# Generating and saving sequence: 1970
# Generating and saving sequence: 1971
# Generating and saving sequence: 1972
# Generating and saving sequence: 1973
# Generating and saving sequence: 1974
# Generating and saving sequence: 1975
# Generating and saving sequence: 1976
# Generating and saving sequence: 1977
# Generating and saving sequence: 1978
# Generating and saving sequence: 1979
# Time Elapsed: 1013.9839472770691

# %% [markdown]
# # Sanity Check on Generated Sequences

# %%
path = os.path.join('data', 'sequences', 'backhand', 'p36_backhand_s3-16-features.npy')

sequence = np.load(path)
sequence
# Out:
# array([[0.88709366, 0.12494116, 0.45012072, ..., 0.08405273, 0.25460133,
#         0.42437977],
#        [1.0727023 , 0.21859236, 0.59378755, ..., 0.13051566, 0.4385659 ,
#         0.32235762],
#        [1.1032057 , 0.20656884, 0.58252573, ..., 0.09273881, 0.50117815,
#         0.2654044 ],
#        ...,
#        [1.0317401 , 0.20162103, 0.5152767 , ..., 0.18383643, 0.40443486,
#         0.5520245 ],
#        [1.1132641 , 0.16671787, 0.6054903 , ..., 0.07819126, 0.40768605,
#         0.5328623 ],
#        [1.0534246 , 0.07527731, 0.55030596, ..., 0.07819483, 0.3145718 ,
#         0.5057335 ]], dtype=float32)
